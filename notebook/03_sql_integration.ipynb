# %%
import os
os.chdir(r'C:\Users\ADITYA RANJAN\OneDrive\Desktop\Airline_project_analyst')
print(os.getcwd())
# Out:
# C:\Users\ADITYA RANJAN\OneDrive\Desktop\Airline_project_analyst

# %%
import pandas as pd
from sqlalchemy import create_engine
print("Libraries loaded")
# Out:
# Libraries loaded

# %%
df = pd.read_csv('cleaned data/active_flights_clean.csv')
print(f"Shape: {df.shape}")
# Out:
# Shape: (1082277, 36)

# %%
engine = create_engine('mysql+mysqlconnector://root:Aditya%407295@localhost/airline_analytics')
print("Connected to MySQL successfully")
# Out:
# Connected to MySQL successfully

# %%
engine = create_engine(
    'mysql+mysqlconnector://root:Aditya%407295@localhost/airline_analytics',
    pool_pre_ping=True
)

with engine.connect() as conn:
    conn.rollback()

print("Connected successfully")
# Out:
# Connected successfully

# %%
print("Loading data into MySQL...")
print("This will take 3-5 minutes. Please wait...")

df.to_sql('flights', con=engine, if_exists='replace', index=False, chunksize=10000)

print("Data loaded successfully")
print(f"Total rows loaded: {len(df):,}")
# Out:
# Loading data into MySQL...
# This will take 3-5 minutes. Please wait...
# Data loaded successfully
# Total rows loaded: 1,082,277
